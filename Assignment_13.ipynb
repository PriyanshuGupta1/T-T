# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyanshuGupta1/TnT/blob/master/Assignment_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
df=pd.read_csv('/content/Social_Network_Ads.csv')
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
cols = ['Age', 'EstimatedSalary', 'Purchased']

# %%
for col in cols:
    le = preprocessing.LabelEncoder()
    df[col] = le.fit_transform(df[col])
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0    1                4          0
# 1   17                5          0
# 2    8               26          0
# 3    9               39          0
# 4    1               57          0

# %%
df.Purchased.value_counts()
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0    1                4          0
# 1   17                5          0
# 2    8               26          0
# 3    9               39          0
# 4    1               57          0

# %%
x_train, x_test, y_train, y_test = train_test_split(df.drop(columns = ['Purchased']), df['Purchased'], test_size = 0.3)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((280, 2), (280,), (120, 2), (120,))

# %%
algos = []
accuracy = []
recall = []
specificity=[]
precision = []
f1Score = []

# %%
algo = "Logistic Regression"
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(algo)

print(confusion_matrix(y_test, y_pred), '\n')
cm1=confusion_matrix(y_test, y_pred)

acc = accuracy_score(y_test, y_pred) 
print('Accuracy:', acc)

rec = recall_score(y_test, y_pred) 
print('Recall:', rec)

sp1=cm1[0][0]/(cm1[0][0]+cm1[0][1])
print('Specificity:', sp1)

pre = precision_score(y_test, y_pred) 
print('Precision:', pre)

f1s = f1_score(y_test, y_pred) 
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
specificity.append(sp1)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
print("\n")
# Out:
# Logistic Regression
# [[69  5]
#  [14 32]]
#
# Accuracy: 0.8416666666666667
# Recall: 0.6956521739130435
# Specificity: 0.9324324324324325
# Precision: 0.8648648648648649
# F score: 0.7710843373493975

# %%
algo="SVM"
svm=SVC()
svm.fit(x_train, y_train)
y_pred = svm.predict(x_test)
print(algo)

print(confusion_matrix(y_test, y_pred), '\n')
cm4=confusion_matrix(y_test, y_pred)

acc = accuracy_score(y_test, y_pred) 
print('Accuracy:', acc)

rec = recall_score(y_test, y_pred) 
print('Recall:', rec)

sp4=cm4[0][0]/(cm4[0][0]+cm4[0][1])
print('Specificity:', sp4)

pre = precision_score(y_test, y_pred) 
print('Precision:', pre)

f1s = f1_score(y_test, y_pred) 
print('F1 score:', f1s)

algos.append(algo)
accuracy.append(acc)
specificity.append(sp4)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
print("\n")
# Out:
# SVM
# [[67  7]
#  [ 4 42]]
#
# Accuracy: 0.9083333333333333
# Recall: 0.9130434782608695
# Specificity: 0.9054054054054054
# Precision: 0.8571428571428571
# F1 score: 0.8842105263157894

# %%
algo = "Decision Tree"
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(algo)

print(confusion_matrix(y_test, y_pred), '\n')
cm3=confusion_matrix(y_test, y_pred)

acc = accuracy_score(y_test, y_pred)
print('Accuracy:', acc)

rec = recall_score(y_test, y_pred)
print('Recall:', rec)

sp3=cm3[0][0]/(cm3[0][0]+cm3[0][1])
print('Specificity:', sp1)

pre = precision_score(y_test, y_pred) 
print('Precision:', pre)

f1s = f1_score(y_test, y_pred) 
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
specificity.append(sp3)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
print("\n")
# Out:
# Decision Tree
# [[67  7]
#  [ 9 37]]
#
# Accuracy: 0.8666666666666667
# Recall: 0.8043478260869565
# Specificity: 0.9324324324324325
# Precision: 0.8409090909090909
# F score: 0.8222222222222223

# %%
algo = "Naive Bayes"
model = GaussianNB()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(algo)

print(confusion_matrix(y_test, y_pred), '\n')
cm4=confusion_matrix(y_test, y_pred)

acc = accuracy_score(y_test, y_pred) 
print('Accuracy:', acc)

rec = recall_score(y_test, y_pred) 
print('Recall:', rec)

sp4=cm4[0][0]/(cm4[0][0]+cm4[0][1])
print('Specificity:', sp4)

pre = precision_score(y_test, y_pred) 
print('Precision:', pre)

f1s = f1_score(y_test, y_pred) 
print('F score:', f1s)

algos.append(algo)
accuracy.append(acc)
specificity.append(sp4)
recall.append(rec)
precision.append(pre)
f1Score.append(f1s)
print("\n")
# Out:
# Naive Bayes
# [[68  6]
#  [ 9 37]]
#
# Accuracy: 0.875
# Recall: 0.8043478260869565
# Specificity: 0.918918918918919
# Precision: 0.8604651162790697
# F score: 0.8314606741573034

# %%
for i in range(4):
    print(algos[i], ':     ', accuracy[i],',  ',specificity[i],',  ', recall[i],',  ', precision[i],',  ', f1Score[i])
# Out:
# Logistic Regression :      0.8416666666666667 ,   0.9324324324324325 ,   0.6956521739130435 ,   0.8648648648648649 ,   0.7710843373493975
# SVM :      0.9083333333333333 ,   0.9054054054054054 ,   0.9130434782608695 ,   0.8571428571428571 ,   0.8842105263157894
# Decision Tree :      0.8666666666666667 ,   0.9054054054054054 ,   0.8043478260869565 ,   0.8409090909090909 ,   0.8222222222222223
# Naive Bayes :      0.875 ,   0.918918918918919 ,   0.8043478260869565 ,   0.8604651162790697 ,   0.8314606741573034

# %%
plt.figure(figsize = (15,8))
plt.bar(algos, accuracy)
plt.show()
