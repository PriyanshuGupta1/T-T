# %%
import pandas as pd
import seaborn as sns

dataset=pd.read_csv("E:\T&T\TnT\Lab3\Social_Network_Ads.csv")
sns.set(style="darkgrid")
sns.lmplot(x='Age', y='EstimatedSalary', data=dataset,fit_reg=True,hue='Purchased')
